# %% [markdown]
# # Travel Booking Agent – Demo
#
# Quick demo of the agentic travel booking system.

# %%
from travel_agent.config import AppConfig
from travel_agent.logging_utils import setup_logging
from travel_agent.llm.client import LLMClient
from travel_agent.agent.runner import AgentRunner
import logging

setup_logging(logging.INFO)
config = AppConfig.from_env()
llm = LLMClient(config)
agent = AgentRunner(llm)

agent.handle_user_input('Find me a one way flight from Hyderabad to London on 2025-11-15 under 60000 INR.')
